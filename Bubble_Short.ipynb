# %% [markdown]
# <a href="https://colab.research.google.com/github/hrswps/SD/blob/main/Bubble_Short.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl -s -o setup.sh https://raw.githubusercontent.com/tproffen/ORCSGirlsPython/master/Algorithms/Helpers/setup_activity2.sh
# !bash setup.sh
# Out:
# Fetching needed files ..
# Done

# %%
# %matplotlib inline
import numpy as np
from Helpers.helpers import *

# %%
data=[29,99,27,41,66,28,44,78,87,19,31,76,58,88,83,97,12,21,44]

print ("Data: ",data)
# Out:
# Data:  [29, 99, 27, 41, 66, 28, 44, 78, 87, 19, 31, 76, 58, 88, 83, 97, 12, 21, 44]

# %%
updateGraph(1,data)

# %%
def bubble_sort(data):
    # We go through the list as many times as there are elements
    for i in range(len(data)):
        # We want the last pair of adjacent elements to be (n-2, n-1)
        for j in range(len(data) - 1):
            if data[j] > data[j+1]:
                # Swap
                data[j], data[j+1] = data[j+1], data[j]

# %%
bubble_sort(data)
print(data)
# Out:
# [12, 19, 21, 27, 28, 29, 31, 41, 44, 44, 58, 66, 76, 78, 83, 87, 88, 97, 99]

# %%
updateGraph(0,data)
